# %%
import pycountry

# %%
country_names = []
for country in pycountry.countries:
    country_names.append(country.name)
    if hasattr(country,'common_name'):
        country_names.append(country.common_name)
    if hasattr(country, 'official_name'):
        country_names.append(country.official_name)
   
        
print country_names
# Out:
# [u'Aruba', u'Afghanistan', u'Islamic Republic of Afghanistan', u'Angola', u'Republic of Angola', u'Anguilla', u'\xc5land Islands', u'Albania', u'Republic of Albania', u'Andorra', u'Principality of Andorra', u'United Arab Emirates', u'Argentina', u'Argentine Republic', u'Armenia', u'Republic of Armenia', u'American Samoa', u'Antarctica', u'French Southern Territories', u'Antigua and Barbuda', u'Australia', u'Austria', u'Republic of Austria', u'Azerbaijan', u'Republic of Azerbaijan', u'Burundi', u'Republic of Burundi', u'Belgium', u'Kingdom of Belgium', u'Benin', u'Republic of Benin', u'Bonaire, Sint Eustatius and Saba', u'Bonaire, Sint Eustatius and Saba', u'Burkina Faso', u'Bangladesh', u"People's Republic of Bangladesh", u'Bulgaria', u'Republic of Bulgaria', u'Bahrain', u'Kingdom of Bahrain', u'Bahamas', u'Commonwealth of the Bahamas', u'Bosnia and Herzegovina', u'Republic of Bosnia and Herzegovina', u'Saint Barth\xe9lemy', u'Belarus', u'Republic of Belarus', u'Belize', u'Bermuda', u'Bolivia, Plurinational State of', u'Bolivia', u'Plurinational State of Bolivia', u'Brazil', u'Federative Republic of Brazil', u'Barbados', u'Brunei Darussalam', u'Bhutan', u'Kingdom of Bhutan', u'Bouvet Island', u'Botswana', u'Republic of Botswana', u'Central African Republic', u'Canada', u'Cocos (Keeling) Islands', u'Switzerland', u'Swiss Confederation', u'Chile', u'Republic of Chile', u'China', u"People's Republic of China", u"C\xf4te d'Ivoire", u"Republic of C\xf4te d'Ivoire", u'Cameroon', u'Republic of Cameroon', u'Congo, The Democratic Republic of the', u'Congo', u'Republic of the Congo', u'Cook Islands', u'Colombia', u'Republic of Colombia', u'Comoros', u'Union of the Comoros', u'Cabo Verde', u'Republic of Cabo Verde', u'Costa Rica', u'Republic of Costa Rica', u'Cuba', u'Republic of Cuba', u'Cura\xe7ao', u'Cura\xe7ao', u'Christmas Island', u'Cayman Islands', u'Cyprus', u'Republic of Cyprus', u'Czechia', u'Czech Republic', u'Germany', u'Federal Republic of Germany', u'Djibouti', u'Republic of Djibouti', u'Dominica', u'Commonwealth of Dominica', u'Denmark', u'Kingdom of Denmark', u'Dominican Republic', u'Algeria', u"People's Democratic Republic of Algeria", u'Ecuador', u'Republic of Ecuador', u'Egypt', u'Arab Republic of Egypt', u'Eritrea', u'the State of Eritrea', u'Western Sahara', u'Spain', u'Kingdom of Spain', u'Estonia', u'Republic of Estonia', u'Ethiopia', u'Federal Democratic Republic of Ethiopia', u'Finland', u'Republic of Finland', u'Fiji', u'Republic of Fiji', u'Falkland Islands (Malvinas)', u'France', u'French Republic', u'Faroe Islands', u'Micronesia, Federated States of', u'Federated States of Micronesia', u'Gabon', u'Gabonese Republic', u'United Kingdom', u'United Kingdom of Great Britain and Northern Ireland', u'Georgia', u'Guernsey', u'Ghana', u'Republic of Ghana', u'Gibraltar', u'Guinea', u'Republic of Guinea', u'Guadeloupe', u'Gambia', u'Islamic Republic of the Gambia', u'Guinea-Bissau', u'Republic of Guinea-Bissau', u'Equatorial Guinea', u'Republic of Equatorial Guinea', u'Greece', u'Hellenic Republic', u'Grenada', u'Greenland', u'Guatemala', u'Republic of Guatemala', u'French Guiana', u'Guam', u'Guyana', u'Republic of Guyana', u'Hong Kong', u'Hong Kong Special Administrative Region of China', u'Heard Island and McDonald Islands', u'Honduras', u'Republic of Honduras', u'Croatia', u'Republic of Croatia', u'Haiti', u'Republic of Haiti', u'Hungary', u'Hungary', u'Indonesia', u'Republic of Indonesia', u'Isle of Man', u'India', u'Republic of India', u'British Indian Ocean Territory', u'Ireland', u'Iran, Islamic Republic of', u'Islamic Republic of Iran', u'Iraq', u'Republic of Iraq', u'Iceland', u'Republic of Iceland', u'Israel', u'State of Israel', u'Italy', u'Italian Republic', u'Jamaica', u'Jersey', u'Jordan', u'Hashemite Kingdom of Jordan', u'Japan', u'Kazakhstan', u'Republic of Kazakhstan', u'Kenya', u'Republic of Kenya', u'Kyrgyzstan', u'Kyrgyz Republic', u'Cambodia', u'Kingdom of Cambodia', u'Kiribati', u'Republic of Kirib ...

# %%
import csv

cities = []
with open('world-cities.csv', 'r') as inp:
        for row in csv.reader(inp):
            if(row and row[3] != "" and row[0]!="name"):
                cities.append(row[0])

cities.append('Bombay')
print cities
# Out:
# ['les Escaldes', 'Andorra la Vella', 'Umm al Qaywayn', 'Ras al-Khaimah', 'Khawr Fakk\xc4\x81n', 'Dubai', 'Dibba Al-Fujairah', 'Dibba Al-Hisn', 'Sharjah', 'Ar Ruways', 'Al Fujayrah', 'Al Ain', 'Ajman', 'Adh Dhayd', 'Abu Dhabi', 'Zaranj', 'Taloqan', 'Sh\xc4\xabn\xe1\xb8\x8fan\xe1\xb8\x8f', 'Shibirgh\xc4\x81n', 'Shahrak', 'Sar-e Pul', 'Sang-e Ch\xc4\x81rak', 'A\xc4\xabbak', 'Rust\xc4\x81q', 'Qarq\xc4\xabn', 'Qar\xc4\x81wul', 'Pul-e Khumr\xc4\xab', 'Paghm\xc4\x81n', 'Nahr\xc4\xabn', 'Maymana', 'Mehtar L\xc4\x81m', 'Maz\xc4\x81r-e Shar\xc4\xabf', 'Lashkar G\xc4\x81h', 'Kushk', 'Kunduz', 'Kh\xc5\x8dst', 'Khulm', 'Kh\xc4\x81sh', 'Khanabad', 'Karukh', 'Kandah\xc4\x81r', 'Kabul', 'Jal\xc4\x81l\xc4\x81b\xc4\x81d', 'Jabal os Saraj', 'Her\xc4\x81t', 'Ghormach', 'Ghazni', 'Gereshk', 'Gard\xc4\x93z', 'Fayzabad', 'Farah', 'Kafir Qala', 'Charikar', 'Barak\xc4\xab Barak', 'B\xc4\x81my\xc4\x81n', 'Balkh', 'Baghl\xc4\x81n', '\xc4\x80rt Khw\xc4\x81jah', '\xc4\x80sm\xc4\x81r', 'Asad\xc4\x81b\xc4\x81d', 'Andkh\xc5\x8dy', 'B\xc4\x81z\xc4\x81rak', 'Markaz-e Woluswal\xc4\xab-ye \xc4\x80ch\xc4\xabn', 'Saint John\xe2\x80\x99s', 'The Valley', 'Sarand\xc3\xab', 'Kuk\xc3\xabs', 'Kor\xc3\xa7\xc3\xab', 'Gjirokast\xc3\xabr', 'Elbasan', 'Burrel', 'Vlor\xc3\xab', 'Tirana', 'Shkod\xc3\xabr', 'Patos Fshat', 'Lushnj\xc3\xab', 'Lezh\xc3\xab', 'La\xc3\xa7', 'Ku\xc3\xa7ov\xc3\xab', 'Kruj\xc3\xab', 'Kavaj\xc3\xab', 'Fier-\xc3\x87if\xc3\xa7i', 'Fier', 'Durr\xc3\xabs', 'Berat', 'Kapan', 'Goris', 'Hats\xe2\x80\x99avan', 'Artashat', 'Ararat', 'Yerevan', 'Ejmiatsin', 'Spitak', 'Sevan', 'Masis', 'Vanadzor', 'Gavarr', 'Hrazdan', 'Armavir', 'Gyumri', 'Ashtarak', 'Abovyan', 'Saurimo', 'Lucapa', 'Luau', 'U\xc3\xadge', 'Soio', 'Nzeto', 'N\xe2\x80\x99dalatando', 'Mbanza Congo', 'Malanje', 'Luanda', 'Caxito', 'Cabinda', 'Sumbe', 'Namibe', 'Menongue', 'Luena', 'Lubango', 'Longonjo', 'Lobito', 'Cuito', 'Huambo', 'Catumbela', 'Catabola', 'Camacupa', 'Caluquembe', 'Ca\xc3\xa1la', 'Benguela', 'Z\xc3\xa1rate', 'Villa Ocampo', 'Villa Lugano', 'Villaguay', 'Villa Gesell', 'Tigre', 'Tandil', 'San Vicente', 'Santo Tom\xc3\xa9', 'Santa Elena', 'San Pedro', 'San Luis del Palmar', 'San Lorenzo', 'San Javier', 'San Isidro', 'Saladas', 'Retiro', 'Resistencia', 'Reconquista', 'Quilmes', 'Puerto Rico', 'Puerto Iguaz\xc3\xba', 'Puerto Esperanza', 'Puerto Eldorado', 'Posadas', 'Pontevedra', 'Piran\xc3\xa9', 'Paso de los Libres', 'Ober\xc3\xa1', 'Necochea', 'Mor\xc3\xb3n', 'Monte Caseros', 'Montecarlo', 'Mercedes', 'Mercedes', 'Mar del Plata', 'Luj\xc3\xa1n', 'La Plata', 'La Paz', 'Jard\xc3\xadn Am\xc3\xa9rica', 'Gualeguaych\xc3\xba', 'Gualeguay', 'Goya', 'Gobernador Ingeniero Valent\xc3\xadn Virasoro', 'General Jos\xc3\xa9 de San Mart\xc3\xadn', 'Garup\xc3\xa1', 'Formosa', 'Fontana', 'Federal', 'Esquina', 'El Soberbio', 'Dolores', 'Curuz\xc3\xba Cuati\xc3\xa1', 'Corrientes', 'Concordia', 'Concepci\xc3\xb3n del Uruguay', 'Colegiales', 'Chajar\xc3\xad', 'Campana', 'Buenos Aires', 'Barranqueras', 'Azul', 'Avellaneda', 'Arist\xc3\xb3bulo del Valle', 'Zapala', 'Yerba Buena', 'Villa Regina', 'Villa Paula de Sarmiento', 'Villa Nueva', 'Villa Mar\xc3\xada', 'Villa Dolores', 'Villa Constituci\xc3\xb3n', 'Villa Carlos Paz', 'Villa \xc3\x81ngela', 'Villa Allende', 'Viedma', 'Victoria', 'Vera', 'Venado Tuerto', 'Veinticinco de Mayo', 'Ushuaia', 'Unquillo', 'Tres Isletas', 'Tres Arroyos', 'Trelew', 'Termas de R\xc3\xado Hondo', 'Tartagal', 'Taf\xc3\xad Viejo', 'Sunchales', 'Santo Tom\xc3\xa9', 'Santiago del Estero', 'Santa Rosa', 'Santa Luc\xc3\xada', 'Santa Fe de la Vera Cruz', 'San Salvador de Jujuy', 'San Ram\xc3\xb3n de la Nueva Or\xc3\xa1n', 'San Rafael', 'San Pedro', 'San Nicol\xc3\xa1s de los Arroyos', 'San Miguel de Tucum\xc3\xa1n', 'San Mart\xc3\xadn de los Andes', 'San Mart\xc3\xadn', 'San Luis', 'San Justo', 'San Juan', 'San Jos\xc3\xa9 de J\xc3\xa1chal', 'San Jorge', 'San Francisco', 'San Fernando del Valle de Catamarca', 'San Antonio Oeste', 'Salta', 'Rufino', 'Rosario', 'R\xc3\xado Tercero', 'R\xc3 ...

# %%
import os
base_directory = os.path.dirname(os.getcwd())
data_directory = os.path.join(base_directory,"Dataset","Sreejita")
file_list = os.listdir(data_directory)
#os.rename('a.txt', 'b.kml')

doc_id = 101
for file in file_list:
    #new_name = str(doc_id) +'.' + file
    #os.rename(file, new_name)
    doc_id += 1
    print file
# Out:
# aber-diamond-rises-on-report-rio-may-sell-mine-stake.txt
# ace-aviation-will-sell-$97million-stake-in-jazz-air.txt
# air-canada-chief-expects-very-good-winter-bookings.txt
# air-canada-introduces-electronic-boarding-passes.txt
# allianz-calls-profit-targets-much-more-challenging.txt
# ambac-gets-1-5-billion-in-capital-to-keep-aaa-grade.txt
# amerigroup-reduces-forecast-for-2008-after-rate-cut.txt
# antisoma-gets-75-million-from-novartis-for-drug.txt
# bally-technologies-says-court-ruled-in-its-favor.txt
# bank-of-communications-profit-rises-more-than-60%.txt
# bhp-may-build-desalination-plant-at-olympic-dam-mine.txt
# bright-dairy-shares-surge-on-milk-price-increase.txt
# bundchen-proves-buffett-savvy-paring-currency-risk.txt
# cambridge-heart-cuts-revenue-forecast-for-the-year.txt
# carlsberg-names-eastern-europe-head-as-new-chief.txt
# carlsberg-wins-european-approval-to-buy-s-n-assets.txt
# carrefour-s-halley-family-will-scrap-shareholder-pact.txt
# cell-genesys-surges-on-prostate-drug-pact-with-takeda.txt
# ceme-posts-3rd-quarter-loss-sales-rise-in-all-markets.txt
# centro-facing-debt-deadline-won-t-rush-asset-sales.txt
# centro-may-cut-profit-forecast-as-loan-costs-rise.txt
# changan-auto-third-quarter-profit-falls-12-on-tax.txt
# china-discovers-$119billion-banking-irregularities.txt
# china-life-may-invest-in-agricultural-bank-cdb.txt
# coca-cola-will-sell-odwalla-juice-based-energy-drink.txt
# company-debt-risk-rises-as-manufacturing-unexpectedly-contracts.txt
# compton-surges-after-biggest-shareholder-urges-sale.txt
# comstar-sees-regional-sales-of-550-million.txt
# comstar-third-quarter-net-hurt-by-196-million-charge.txt
# druckenmiller-bets-on-revival-of-failed-exxon-well.txt
# dynegy-forecasts-2008-profit-below.txt
# euros-in-new-york-prop-up-economy-as-dollar-falls.txt
# femsa-beer-prices-rising-by-expected-2008-inflation.txt
# fonterra-eyes-australian-fresh-milk-market-for-growth.txt
# france-telecom-raised-to-buy-at-exane-on-earnings.txt
# game-console-sales-rose-nintendo-leads.txt
# gazit-globe-of-israel-doubles-profit-on-rental-income.txt
# golden-telecom-third-quarter-net-income-triples.txt
# google-wins-yahoo-support-for-opensocial-forms-group.txt
# gramercy-to-buy-lewis-ranieri-s-afr-for-1-1-billion.txt
# harpercollins-to-print-frey-s-bright-shiny-morning.txt
# hina-life-may-sell-stake-to-overseas-investors.txt
# hollywood-studios-set-sales-record-on-ticket-prices.txt
# hsbc-to-restore-bocom-ownership-to-original-level.txt
# imax-quarterly-loss-widens-on-transition-to-digital.txt
# indonesia-stocks-raised-australia-cut-at-merrill.txt
# investor-ab-net-asset-value-drops-on-market-turmoil.txt
# irish-mortgage-lending-eases-to-slowest-in-a-decade.txt
# kazakhstan-to-send-nuclear-fuel-to-japan-power-plants.txt
# knight-acquires-edgetrade-algorithmic-brokerage.txt
# knight-profit-falls-48-percent-on-hedge-fund-fees.txt
# liberty-says-the-value-of-its-u-k-malls-declined.txt
# limited-seeks-same-store-sales-gain-of-as-much-as-5.txt
# lockheed-saic-win-part-of-4-billion-medicare-award.txt
# lufthansa-criticizes-russian-request-for-siberia-cargo-hub-move.txt
# lukoil-billionaire-alekperov-holds-oil-talks-in-iraq.txt
# man-ag-appoints-member-to-scania-nominating-committee.txt
# mbia-ambac-gain-after-calyon-says-stocks-are-cheap.txt
# mbia-approves-lowest-executive-bonuses-in-its-history.txt
# medigene-loss-widens-on-higher-research-expenses.txt
# metropcs-scraps-offer-to-acquire-rival-leap-wireless.txt
# monolines-may-need-3-7-billion-to-insure.txt
# n-z-oil-gas-says-taranui-well-to-be-abandoned.txt
# new-york-times-dow-jones-accord-with-writers-voided.txt
# news-corp-s-fox-business-network.txt
# nexans-to-buy-cable-unit-of-madeco.txt
# novolipetsk-steel-agrees-to-buy-a-stake-in-maxi-group.txt
# pantaloon-may-consider-separating-its-hypermarket.txt
# peoplesupport-falls-after-forecast-misses-estimates.txt
# peruvian-copper-production-increased-in-september.txt
# pmi-falls-on-expected-loss-from-borrower-defaults.txt
# renault-agrees-to-buy-25-stake-in-russia-s-avtovaz.txt
# rosneft-may-sell-shares-to-reduce-debt-swap-stock.txt
# rosneft-plans-to-upgrade-former-yukos-oil-refineries.txt
# royal-dutch-shell-may-book-oil-reserves-in-central-russia.txt
# s&n-expects-outcome-to-carlsberg-arbitration-by-july.txt
# saic-names-lawrence-prior-chief-operating-officer.txt
# saic-says-nasa-exercises-option-on-2004-contract.txt
# saic-wins-naval-award-worth-as-much-as-459-million.txt
# saks-nordstrom-fall-as-u-s-luxury-spending-slows.txt
# saks-says-earnings-jump-on-shoes-tourist-spending.txt
# samsung-fire-seoul-office-raided.txt
# samsung-group-headquarters-raided.txt
# shaw-workers-sue-over-exposure-in-radioactive-cleanup.txt
# sinopec-cuts-ethylene-output-to-boost-diesel-supply.txt
# soriana-to-pay-1-35-billion-for-gigante-s-stores.txt
# stillwater-reports-loss-after-strike-cuts-production.txt
# sun-watson-defer-on-copy-of-novartis-dementia-drug.txt
# televisa-films-chinese-version-of-colombian-tv-show.txt
# toronto-airport-world-s-most-expensive-cuts-fees.txt
# u-k-union-recommends-members-back-royal-mail-deal.txt
# virgin-america-lost-34-8-million-in-first-3-months.txt
# virgin-america-wants-chief-to-stay-three-more-months.txt
# vtb-group-third-quarter-profit-more-than-doubles.txt
# vtb-sells-5-eads-stake-to-russia-s-vnesheconombank.txt
# wavefield-calls-for-new-review-of-tgs-nopec-merger.txt
# weber-deutsche-telecom-riaa-intellectual-property.txt
# wesfarmers-hardware-sales-rose-11-in-first-4-months.txt
# wet-seal-shares-have-biggest-drop-since-04-on-profit.txt
# wheeling-pitt-investigates-substantial-gas-deposits.txt

# %%
des = open('designations.txt').read().split('\n')
des = [x.lower() for x in des]

# %%
print des
# Out:
# ['chief executive officer', 'chief financial officer', 'co-chief executive', 'chief investment officer', 'analyst', 'ceo', 'cio', 'cto', 'cfo', 'manager', 'director', 'president', 'vice-president', 'vice president', 'chief', 'executive', 'officer', 'officers', 'analysts', 'managers', 'directors', 'co-chief', 'co chief']

# %%
inst = "Victoria's  Secret"

for d in inst.split():
    print d

if any(d in inst.split() for d in des):
    print(inst)

if "'s" in inst:
    print "Apos"
# Out:
# Victoria's
# Secret
# Apos
