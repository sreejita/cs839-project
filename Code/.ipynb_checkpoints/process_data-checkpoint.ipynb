# %%
import os
import sklearn
import pandas as pd
import csv

# %%
n_gram_value = 5

# %%
def get_ngrams(input_list, n):    
    return zip(*[input_list[i:] for i in range(n)])

# %%
def getAllPossibleWords(file_path): 
    possible_words=[]
    with open(file_path) as f:
        for line in f:
            for word in line.split():
                possible_words.append(word)     
   # possible_words = map(lambda x : unidecode.unidecode(x),possible_words)
    for c in ['`',"[","]","(",")","\"",".","''",","]:
        possible_words = map(lambda x: x.replace(c,""),possible_words)
        
    possible_words = map(lambda x: x.replace('&','And'),possible_words)
    #possible_words = map(lambda x: x.replace('of','Of'),possible_words)
    possible_words=filter(lambda x:len(x)>0,possible_words)    
    
    return possible_words

# %%
def getListFromFiles(filename):
    file_path = os.path.join(os.getcwd(),filename)
    info_list = []
    with open(file_path) as f:
        for line in f:
            for word in line.split():
                info_list.append(word)
    return info_list

# %%
def writeToCsv(processed_list):
    with open("output-sreejita.csv",'wb') as resultFile:
        wr = csv.writer(resultFile, dialect='excel')
        #for row in processed_list:
        wr.writerows(processed_list)

# %%
'''def preprocessing(possible_words,doc_id):    
    suffix_list = getListFromFiles("company-suffixes.txt")
    prefix_list = getListFromFiles("company-prefixes.txt")    
    common_words = getListFromFiles("common-words.txt")
    preprocessed_list =[]    
    marked_list=[]
    word_number=len(possible_words)
    for i in range(5,0,-1):
        word_count=0
        ngram_list = get_ngrams(possible_words,i)
        for ngram in ngram_list:            
            #print ngram   
            
            #if markup is both at the beginning or at the end of the word group accept and label as 1
            if(len(ngram)>1 and '<markup>' in ngram[0] and '</markup>' in ngram[len(ngram)-1] and
              all((word[0].isupper() or "markup" in word) for word in ngram) and 
              ["<markup>" in word for word in ngram].count(True)==1):
                preprocessed_list.append([' '.join(ngram),doc_id,word_count,word_count+i-1,1])
            
            #get all instances of format <markup>Microsoft</markup>
            if(len(ngram)==1 and '</markup>' in ngram[0] and '<markup>' in ngram[0]):
                preprocessed_list.append([' '.join(ngram),doc_id,word_count,word_count+i-1,1])            
                    
            else:
                #prune away all n grams with non uppercase first character
                if(all(word[0].isupper() and "markup" not in word for word in ngram)):       
                    
                    # prune common words
                    if(any(word not in common_words for word in ngram)):                        
                        preprocessed_list.append([' '.join(ngram),doc_id,word_count,word_count+i-1,0])

                    #prune unigrams 
                    elif(i==1 and word_number> word_count+1):                        
                        
                        #add the unigram to the list if the next word begins with lower case
                        if(possible_words[word_count+1][0].islower()):
                            preprocessed_list.append([' '.join(ngram),doc_id,word_count,word_count+i-1,0])  
            word_count = word_count+1
    return preprocessed_list   '''
# Out:
# 'def preprocessing(possible_words,doc_id):    \n    suffix_list = getListFromFiles("company-suffixes.txt")\n    prefix_list = getListFromFiles("company-prefixes.txt")    \n    common_words = getListFromFiles("common-words.txt")\n    preprocessed_list =[]    \n    marked_list=[]\n    word_number=len(possible_words)\n    for i in range(5,0,-1):\n        word_count=0\n        ngram_list = get_ngrams(possible_words,i)\n        for ngram in ngram_list:            \n            #print ngram   \n            \n            #if markup is both at the beginning or at the end of the word group accept and label as 1\n            if(len(ngram)>1 and \'<markup>\' in ngram[0] and \'</markup>\' in ngram[len(ngram)-1] and\n              all((word[0].isupper() or "markup" in word) for word in ngram) and \n              ["<markup>" in word for word in ngram].count(True)==1):\n                preprocessed_list.append([\' \'.join(ngram),doc_id,word_count,word_count+i-1,1])\n            \n            #get all instances of format <markup>Microsoft</markup>\n            if(len(ngram)==1 and \'</markup>\' in ngram[0] and \'<markup>\' in ngram[0]):\n                preprocessed_list.append([\' \'.join(ngram),doc_id,word_count,word_count+i-1,1])            \n                    \n            else:\n                #prune away all n grams with non uppercase first character\n                if(all(word[0].isupper() and "markup" not in word for word in ngram)):       \n                    \n                    # prune common words\n                    if(any(word not in common_words for word in ngram)):                        \n                        preprocessed_list.append([\' \'.join(ngram),doc_id,word_count,word_count+i-1,0])\n\n                    #prune unigrams \n                    elif(i==1 and word_number> word_count+1):                        \n                        \n                        #add the unigram to the list if the next word begins with lower case\n                        if(possible_words[word_count+1][0].islower()):\n                            preprocessed_list.append([\' \'.join(ngram),doc_id,word_count,word_count+i-1,0])  \n            word_count = word_count+1\n    return preprocessed_list   '

# %%
def preprocessing(possible_words,doc_id):    
    suffix_list = getListFromFiles("company-suffixes.txt")
    prefix_list = getListFromFiles("company-prefixes.txt")    
    common_words = getListFromFiles("common-words.txt")
    preprocessed_list =[]    
    marked_list=[]
    word_number=len(possible_words)
    for i in range(5,0,-1):
        word_count=0
        ngram_list = get_ngrams(possible_words,i)
        for ngram in ngram_list:            
            #print ngram   
            
            #if markup is both at the beginning or at the end of the word group accept and label as 1
            if(len(ngram)>1 and '<markup>' in ngram[0] and '</markup>' in ngram[len(ngram)-1] and
              all((word[0].isupper() or "markup" in word) for word in ngram) and 
              ["<markup>" in word for word in ngram].count(True)==1): 
                company_tuple = ngram
                for string in ["<markup>","</markup>"]:
                    company_tuple = map(lambda x : x.replace(string,""),company_tuple)                
                preprocessed_list.append([' '.join(company_tuple),doc_id,word_count,word_count+i-1,1])
            
            #get all instances of format <markup>Microsoft</markup>
            elif(len(ngram)==1 and '</markup>' in ngram[0] and '<markup>' in ngram[0]):
                
                company_tuple = ngram
                for string in ["<markup>","</markup>"]:
                    company_tuple = map(lambda x : x.replace(string,""),company_tuple) 
                
                preprocessed_list.append([' '.join(company_tuple),doc_id,word_count,word_count+i-1,1])            
                    
            else:
                #prune away all n grams with non uppercase first character
                if(all(word[0].isupper() and "markup" not in word for word in ngram)):  
                    
                    #prune unigrams 
                    if(i==1):                        
                        if(ngram[0] not in suffix_list):
                            if(word_number> word_count+1 and ngram[0] not in common_words):
                                #add the unigram to the list if the next word begins with lower case
                                if(possible_words[word_count+1][0].islower()):
                                    preprocessed_list.append([' '.join(ngram),doc_id,word_count,word_count+i-1,0])
                    
                    #prune common words
                    elif(any(word not in common_words for word in ngram)):                        
                        preprocessed_list.append([' '.join(ngram),doc_id,word_count,word_count+i-1,0])                   

                    
                     
            word_count = word_count+1
    return preprocessed_list

# %%
def generateFeatures(filename, processed_list,possible_words):
    
    company_suffixes = getListFromFiles("company-suffixes.txt")
    company_prefixes = getListFromFiles("company-prefixes.txt")    
    company_list=[]
    splittedFilename = filename.split("-")
    i=0
    print "possible_words- "  
    print possible_words
    for company in processed_list:
        i+=1
        #Feature 1 : name has any prefix or suffix of a company 
        #if company name has any one of the suffixes or prefixes set it to true 
        hasCompanyid=0        
        if(company[0].split()[-1] in company_suffixes or company[0].split()[0] in company_prefixes):
            hasCompanyid = 1
            company_list.append(company[0])            
        #company.append(hasCompanyid)
        
        
        #has Company name at the beginning ?
        #Feature 2: name occurs at the beginning of a company name
        hasCompanyNameFirst = 0
        l1= [x for x in company[0].split() if x not in company_prefixes]
        l2=[]
        for comp in company_list:    
            if(comp.split()[0] in company_prefixes):
                l2.append(" ".join(comp.split()[1:]))
            else:
                l2.append(comp)
        if(any(word in l2 for word in l1)):
            hasCompanyNameFirst = 1
        elif(any(company[0].split()[0]== word.split()[0] for word in company_list)):
            hasCompanyNameFirst = 1 
        
            
        
        #has Company name as a substring ?
        #Feature 3: name is a substring in the company name
        hasNameSubstring=0
        for comp in company_list:
            l1 = company[0].split()
            l2 = comp.split()
            if(len(set(l1)&set(l2)) > 0 ):
                hasNameSubstring=1       
       
         
        
        #Feature 4: name in filename
        isInFilename = 0
        splittedInstance = company[0].split()
        for sp in splittedInstance:
            if sp.lower() in splittedFilename:
                isInFilename = 1 
        
        
        #Feature 5-y - Check neibhouring words - check 3 words before and 3 words after
        starting_loc = company[2]
        ending_loc = company[3]
        words_before_starting_loc = []
        words_after_ending_loc = []
        i= starting_loc-1
        count = 1
        while i >= 0 and count <= 3:
            words_before_starting_loc.append(possible_words[company[2]-count])
            i-=1
            count+=1
        
        i = ending_loc+1
        count = 1
        while i < len(possible_words) and count <= 3:
            words_after_ending_loc.append(possible_words[company[3]+count])
            i+=1
            count+=1
        
        #Feature 5 - Check for word "based" before the company
        has_based = 0
        for word in words_before_starting_loc:
            if "based" in word.lower():
                has_based = 1
        
        #Feature 6 "'s" is after the company
        has_apostrophe_s = 0
        for word in words_after_ending_loc:
            if "'s" in word.lower():
                has_apostrophe_s = 1
        '''
        #Feature 7 "," is after/before the company
        has_comma = 0
        for word in words_after_ending_loc:
            if "," in word.lower():
                has_comma = 1
        '''
        for word in words_before_starting_loc:
            if "," in word.lower():
                has_comma = 1
        
        #Feature 8 designations before/after company
        desig = open('designations.txt').read().split('\n')
        desig_lower = [x.lower() for x in desig]
        has_desig = 0
        for word in words_after_ending_loc:
            if word.lower() in desig_lower:
                has_desig = 1
              
        for word in words_before_starting_loc:
            if word.lower() in desig_lower:
                has_desig = 1 
         
        #Feature 9 "said/told" in the before company
        has_said = 0
        for word in words_before_starting_loc:
            if "said" in word.lower() or "told" in word.lower():
                has_said = 1
        
            
        #Feature 10 company not surrounded by prefix or suffix
        
        print "company:- " + company[0]
        print "words_after_ending_loc"
        print words_after_ending_loc
        print "words_before_starting_loc"
        print words_before_starting_loc
        
        company.extend([hasCompanyid, hasCompanyNameFirst, hasNameSubstring, isInFilename, has_based, has_apostrophe_s, has_comma, has_desig, has_bracket])

# %%
base_directory = os.path.dirname(os.getcwd())
data_directory = os.path.join(base_directory,"Dataset","Example")
file_list = os.listdir(data_directory)
possible_words=[]
processed_list=[]
count=0
#doc_id = 101
for file in file_list:
    relevant_filename = file[4:-4]
    doc_id = file[0:3]
    #print(doc_id)
    #if(int(doc_id)!=95):
    #    continue    
    possible_words = getAllPossibleWords(os.path.join(data_directory,file))     
    
    #start from here .. processessed list has the structure[[word,doc_id,word_count_start,word_count_end,label]]
    ''''processed_list.append(preprocessing(possible_words,doc_id))
    writeToCsv(processed_list)'''
    processed_list_for_doc = preprocessing(possible_words,doc_id)
    #print processed_list_for_doc
    generateFeatures(relevant_filename, processed_list_for_doc,possible_words)
    processed_list.extend(processed_list_for_doc)
    #writeToCsv(processed_list)
# Out:
# possible_words-
# ['<markup>Maanshan', 'Iron', 'And', 'Steel', 'Co</markup>', '323', 'China', "'s", 'second-biggest', 'Hong', 'Kong-listed', 'steelmaker', 'had', 'the', 'rating', 'on', 'its', 'stock', 'raised', 'by', '<markup>Credit', 'Suisse', 'Group</markup>', 'citing', 'higher', 'profit', '<markup>Maanshan', 'Steel</markup>', 'was', 'raised', 'to', 'outperform', 'from', 'neutral', 'Hong', 'Kong-based', 'analysts', 'Trina', 'Chen', 'and', 'Mick', 'Mi', 'said', 'in', 'a', 'report', 'today', '<markup>Maanshan', 'Steel</markup>', "'s", 'efforts', 'to', 'streamline', 'production', 'of', 'railway-carriage', 'wheels', 'will', 'boost', 'output', 'by', '50', 'percent', 'by', '2008', 'raising', 'earnings', '13', 'percent', 'the', 'report', 'said', 'China', 'plans', 'to', 'spend', '100', 'billion', 'yuan', '$13', 'billion', 'by', '2020', 'to', 'extend', 'its', 'rail', 'network', 'by', '35', 'percent', 'fueling', 'demand', 'for', 'carriage', 'wheels', 'Domestic', 'wheel', 'demand', 'is', 'forecast', 'to', 'grow', 'by', '60', 'percent', 'by', '2010', '<markup>Credit', 'Suisse</markup>', 'said', '<markup>Maanshan</markup>', 'currently', 'holds', 'more', 'than', 'two-thirds', 'of', 'the', 'market', 'it', 'said', 'The', '<markup>Maanshan</markup>', 'earnings', 'support', 'and', 'surprise', 'is', 'likely', 'its', 'wheel', 'production', 'the', 'analysts', 'said', 'in', 'the', 'report', 'We', 'expect', 'the', 'rail-wheel', 'market', 'to', 'remain', 'tight', 'in', 'the', 'context', 'of', "China's", 'railway', 'expansion', 'as', 'well', 'as', 'upgrading', 'demand', 'Profit', 'from', 'making', 'the', 'wheels', 'rose', 'to', 'more', 'than', '4000', 'yuan', 'a', 'ton', 'last', 'year', 'from', '600', 'yuan', 'in', '2004', '<markup>Credit', 'Suisse</markup>', 'said', 'The', 'wheels', 'accounted', 'for', '3', 'percent', 'of', 'the', 'output', 'of', '<markup>Maanshan</markup>', 'last', 'year', 'compared', 'with', 'an', 'estimated', '27', 'percent', 'of', 'company', 'profit', '<markup>Maanshan</markup>', 'stock', 'fell', '02', 'percent', 'to', 'HK$457', 'in', 'Hong', 'Kong', 'at', '10:57', 'am', 'local', 'time', 'The', 'shares', 'have', 'gained', '83', 'percent', 'over', 'the', 'past', 'year', '<markup>Credit', 'Suisse</markup>', 'has', 'a', 'share-price', 'target', 'of', 'HK$590', 'The', 'brokerage', 'raised', 'the', 'steel', "mill's", 'rating', 'to', 'neutral', 'from', 'underperform', 'on', 'Oct', '19', 'citing', 'an', 'improved', 'outlook', 'for', 'steel', 'prices', 'and', 'rising', 'production', 'capacity']
# company:- Maanshan Iron And Steel Co
# words_after_ending_loc
# ['323', 'China', "'s"]
# words_before_starting_loc
# []
# company:- Iron And Steel
# words_after_ending_loc
# ['Co</markup>', '323', 'China']
# words_before_starting_loc
# ['<markup>Maanshan']
# company:- Credit Suisse Group
# words_after_ending_loc
# ['citing', 'higher', 'profit']
# words_before_starting_loc
# ['by', 'raised', 'stock']
# company:- Iron And
# words_after_ending_loc
# ['Steel', 'Co</markup>', '323']
# words_before_starting_loc
# ['<markup>Maanshan']
# company:- And Steel
# words_after_ending_loc
# ['Co</markup>', '323', 'China']
# words_before_starting_loc
# ['Iron', '<markup>Maanshan']
# company:- Hong Kong-listed
# words_after_ending_loc
# ['steelmaker', 'had', 'the']
# words_before_starting_loc
# ['second-biggest', "'s", 'China']
# company:- Maanshan Steel
# words_after_ending_loc
# ['was', 'raised', 'to']
# words_before_starting_loc
# ['profit', 'higher', 'citing']
# company:- Hong Kong-based
# words_after_ending_loc
# ['analysts', 'Trina', 'Chen']
# words_before_starting_loc
# ['neutral', 'from', 'outperform']
# company:- Trina Chen
# words_after_ending_loc
# ['and', 'Mick', 'Mi']
# words_before_starting_loc
# ['analysts', 'Kong-based', 'Hong']
# company:- Mick Mi
# words_after_ending_loc
# ['said', 'in', 'a']
# words_before_starting_loc
# ['and', 'Chen', 'Trina']
# company:- Maanshan Steel
# words_after_ending_loc
# ["'s", 'efforts', 'to']
# words_before_starting_loc
# ['today', 'report', 'a']
# company:- Credit Suisse
# words_after_ending_loc
# ['said', '<markup>Maanshan</markup>', 'currently']
# words_before_starting_loc
# ['2010', 'by', 'percent']
# company:- Credit Suisse
# words_after_ending_loc
# ['said', 'The', 'wheels']
# words_before_starting_loc
# ['2004', 'in', 'yuan']
# company:- Hong Kong
# words_after_ending_loc
# ['at', '10:57', 'am']
# words_before_starting_loc
# ['in', 'HK$457', 'to']
# company:- Credit Suisse
# words_after_ending_loc
# ['has', 'a', 'share-price']
# words_before_starting_loc
# ['year', 'past', 'the']
# company:- HK$590 The
# words_after_ending_loc
# ['brokerage', 'raised', 'the']
# words_before_starting_loc
# ['of', 'target', 'share-price']
# company:- Kong-listed
# words_after_ending_loc
# ['steelmaker', 'had', 'the']
# words_before_starting_loc
# ['Hong', 'second-biggest', "'s"]
# company:- Kong-based
# words_after_ending_loc
# ['analysts', 'Trina', 'Chen']
# words_before_starting_loc
# ['Hong', 'neutral', 'from']
# company:- Chen
# words_after_ending_loc
# ['and', 'Mick', 'Mi']
# words_before_starting_loc
# ['Trina', 'analysts', 'Kong-based']
# company:- Mi
# words_after_ending_loc
# ['said', 'in', 'a']
# words_before_starting_loc
# ['Mick', 'and', 'Chen']
# company:- China
# words_after_ending_loc
# ['plans', 'to', 'spend']
# words_before_starting_loc
# ['said', 'report', 'the']
# company:- Domestic
# words_after_ending_loc
# ['wheel', 'demand', 'is']
# words_before_starting_loc
# ['wheels', 'carriage', 'for']
# company:- Maanshan
# words_after_ending_loc
# ['currently', 'holds', 'more']
# words_before_starting_loc
# ['said', 'Suisse</markup>', '<markup>Credit']
# company:- Maanshan
# words_after_ending_loc
# ['earnings', 'support', 'and']
# words_before_starting_loc
# ['The', 'said', 'it']
# company:- We
# words_after_ending_loc
# ['expect', 'the', 'rail-wheel']
# words_before_starting_loc
# ['report', 'the', 'in']
# company:- China's
# words_after_ending_loc
# ['railway', 'expansion', 'as']
# words_before_starting_loc
# ['of', 'context', 'the']
# company:- Profit
# words_after_ending_loc
# ['from', 'making', 'the']
# words_before_starting_loc
# ['demand', 'upgrading', 'as']
# company:- Maanshan
# words_after_ending_loc
# ['last', 'year', 'compared']
# words_before_starting_loc
# ['of', 'output', 'the']
# company:- Maanshan
# words_after_ending_loc
# ['stock', 'fell', '02']
# words_before_starting_loc
# ['profit', 'company', 'of']
# company:- HK$457
# words_after_ending_loc
# ['in', 'Hong', 'Kong']
# words_before_starting_loc
# ['to', 'percent', '02']
# company:- Kong
# words_after_ending_loc
# ['at', '10:57', 'am']
# words_before_starting_loc
# ['Hong', 'in', 'HK$457']
# possible_words-
# ['<markup>Absa', 'Group', 'Ltd</markup>', 'ASA', 'South', "Africa's", 'biggest', 'retail', 'bank', 'fired', 'Danisa', 'Baloyi', 'as', 'a', 'director', 'because', 'of', 'her', 'involvement', 'with', '<markup>Fidentia', 'Asset', 'Management', 'Ltd</markup>', 'the', 'money', 'manager', 'placed', 'under', 'administration', 'Baloyi', 'said', 'she', 'plans', 'to', 'sue', '<markup>Absa</markup>', 'for', 'wrongful', 'dismissal', '<markup>Absa</markup>', 'with', 'immediate', 'effect', 'terminated', 'the', 'services', 'of', 'Baloyi', 'a', 'non-executive', 'director', 'of', 'its', 'banking', 'unit', 'and', 'the', 'holding', 'company', 'Johannesburg-based', '<markup>Absa</markup>', 'said', 'in', 'an', 'e-mailed', 'statement', 'today', 'Baloyi', 'said', '<markup>Absa</markup>', "didn't", 'give', 'her', 'the', 'benefit', 'of', 'the', 'doubt', 'and', 'will', 'seek', 'legal', 'recourse', 'against', 'the', 'lender', 'she', 'said', 'in', 'a', 'separate', 'e-mail', 'Cape', 'Town-based', '<markup>Fidentia</markup>', 'was', 'put', 'under', 'court-ordered', 'administration', 'on', 'Feb', '1', 'for', 'allegedly', 'breaching', 'its', 'investment', 'mandate', 'and', 'stealing', 'client', 'funds', 'Baloyi', 'is', 'a', 'director', 'of', 'Living', 'Hands', 'a', '<markup>Fidentia</markup>', 'unit', 'that', 'administered', 'the', 'Living', 'Hands', 'Umbrella', 'Trust', 'which', 'may', 'have', 'lost', 'as', 'much', 'as', '19', 'billion', 'rand', '$257', 'million', 'through', 'maladministration', 'according', 'to', 'court', 'documents', '<markup>Fidentia</markup>', 'Chairman', 'Arthur', 'Brown', 'and', 'director', 'Graham', 'Maddock', 'were', 'granted', 'bail', 'of', '1', 'million', 'rand', 'each', 'by', 'a', 'Cape', 'Town', 'court', 'yesterday', 'pending', 'their', 'trial', 'on', 'charges', 'they', 'stole', 'as', 'much', 'as', '21', 'billion', 'rand', 'of', "clients'", 'funds', 'and', 'violated', 'tax', 'and', 'company', 'laws', 'They', 'have', 'denied', 'the', 'allegations', 'Brown', 'is', 'still', 'in', 'jail', 'after', 'failing', 'to', 'raise', 'bail', 'the', 'South', 'African', 'Press', 'Association', 'said', 'citing', "Brown's", 'lawyers', 'who', 'they', "didn't", 'identify', '<markup>Absa</markup>', 'is', 'controlled', 'by', '<markup>Barclays', 'Plc</markup>', 'the', "UK's", 'third-largest', 'bank', 'To', 'contact', 'the', 'reporter', 'on', 'this', 'story:', 'Vernon', 'Wessels', 'in', 'Johannesburg', 'at', 'vwessels@bloombergnet', 'To', 'contact', 'the', 'editors', 'responsible', 'for', 'this', 'story:', 'Adrian', 'Cox', 'at', 'acox2@bloombergnet', 'Frank', 'Connelly', 'at', 'fconnelly@bloombergnet']
# company:- Fidentia Asset Management Ltd
# words_after_ending_loc
# ['the', 'money', 'manager']
# words_before_starting_loc
# ['with', 'involvement', 'her']
# company:- Living Hands Umbrella Trust
# words_after_ending_loc
# ['which', 'may', 'have']
# words_before_starting_loc
# ['the', 'administered', 'that']
# company:- South African Press Association
# words_after_ending_loc
# ['said', 'citing', "Brown's"]
# words_before_starting_loc
# ['the', 'bail', 'raise']
# company:- Absa Group Ltd
# words_after_ending_loc
# ['ASA', 'South', "Africa's"]
# words_before_starting_loc
# []
# company:- ASA South Africa's
# words_after_ending_loc
# ['biggest', 'retail', 'bank']
# words_before_starting_loc
# ['Ltd</markup>', 'Group', '<markup>Absa']
# company:- Living Hands Umbrella
# words_after_ending_loc
# ['Trust', 'which', 'may']
# words_before_starting_loc
# ['the', 'administered', 'that']
# company:- Hands Umbrella Trust
# words_after_ending_loc
# ['which', 'may', 'have']
# words_before_starting_loc
# ['Living', 'the', 'administered']
# company:- Chairman Arthur Brown
# words_after_ending_loc
# ['and', 'director', 'Graham']
# words_before_starting_loc
# ['<markup>Fidentia</markup>', 'documents', 'court']
# company:- South African Press
# words_after_ending_loc
# ['Association', 'said', 'citing']
# words_before_starting_loc
# ['the', 'bail', 'raise']
# company:- African Press Association
# words_after_ending_loc
# ['said', 'citing', "Brown's"]
# words_before_starting_loc
# ['South', 'the', 'bail']
# company:- ASA South
# words_after_ending_loc
# ["Africa's", 'biggest', 'retail']
# words_before_starting_loc
# ['Ltd</markup>', 'Group', '<markup>Absa']
# company:- South Africa's
# words_after_ending_loc
# ['biggest', 'retail', 'bank']
# words_before_starting_loc
# ['ASA', 'Ltd</markup>', 'Group']
# company:- Danisa Baloyi
# words_after_ending_loc
# ['as', 'a', 'director']
# words_before_starting_loc
# ['fired', 'bank', 'retail']
# company:- Asset Management
# words_after_ending_loc
# ['Ltd</markup>', 'the', 'money']
# words_before_starting_loc
# ['<markup>Fidentia', 'with', 'involvement']
# company:- Cape Town-based
# words_after_ending_loc
# ['<markup>Fidentia</markup>', 'was', 'put']
# words_before_starting_loc
# ['e-mail', 'separate', 'a']
# company:- Living Hands
# words_after_ending_loc
# ['a', '<markup>Fidentia</markup>', 'unit']
# words_before_starting_loc
# ['of', 'director', 'a']
# company:- Living Hands
# words_after_ending_loc
# ['Umbrella', 'Trust', 'which']
# words_before_starting_loc
# ['the', 'administered', 'that']
# company:- Hands Umbrella
# words_after_ending_loc
# ['Trust', 'which', 'may']
# words_before_starting_loc
# ['Living', 'the', 'administered']
# company:- Umbrella Trust
# words_after_ending_loc
# ['which', 'may', 'have']
# words_before_starting_loc
# ['Hands', 'Living', 'the']
# company:- Chairman Arthur
# words_after_ending_loc
# ['Brown', 'and', 'director']
# words_before_starting_loc
# ['<markup>Fidentia</markup>', 'documents', 'court']
# company:- Arthur Brown
# words_after_ending_loc
# ['and', 'director', 'Graham']
# words_before_starting_loc
# ['Chairman', '<markup>Fidentia</markup>', 'documents']
# company:- Graham Maddock
# words_after_ending_loc
# ['were', 'granted', 'bail']
# words_before_starting_loc
# ['director', 'and', 'Brown']
# company:- Cape Town
# words_after_ending_loc
# ['court', 'yesterday', 'pending']
# words_before_starting_loc
# ['a', 'by', 'each']
# company:- South African
# words_after_ending_loc
# ['Press', 'Association', 'said']
# words_before_starting_loc
# ['the', 'bail', 'raise']
# company:- African Press
# words_after_ending_loc
# ['Association', 'said', 'citing']
# words_before_starting_loc
# ['South', 'the', 'bail']
# company:- Press Association
# words_after_ending_loc
# ['said', 'citing', "Brown's"]
# words_before_starting_loc
# ['African', 'South', 'the']
# company:- Barclays Plc
# words_after_ending_loc
# ['the', "UK's", 'third-largest']
# words_before_starting_loc
# ['by', 'controlled', 'is']
# company:- Vernon Wessels
# words_after_ending_loc
# ['in', 'Johannesburg', 'at']
# words_before_starting_loc
# ['story:', 'this', 'on']
# company:- Adrian Cox
# words_after_ending_loc
# ['at', 'acox2@bloombergnet', 'Frank']
# words_before_starting_loc
# ['story:', 'this', 'for']
# company:- Frank Connelly
# words_after_ending_loc
# ['at', 'fconnelly@bloombergnet']
# words_before_starting_loc
# ['acox2@bloombergnet', 'at', 'Cox']
# company:- Africa's
# words_after_ending_loc
# ['biggest', 'retail', 'bank']
# words_before_starting_loc
# ['South', 'ASA', 'Ltd</markup>']
# company:- Baloyi
# words_after_ending_loc
# ['as', 'a', 'director']
# words_before_starting_loc
# ['Danisa', 'fired', 'bank']
# company:- Baloyi
# words_after_ending_loc
# ['said', 'she', 'plans']
# words_before_starting_loc
# ['administration', 'under', 'placed']
# company:- Absa
# words_after_ending_loc
# ['for', 'wrongful', 'dismissal']
# words_before_starting_loc
# ['sue', 'to', 'plans']
# company:- Absa
# words_after_ending_loc
# ['with', 'immediate', 'effect']
# words_before_starting_loc
# ['dismissal', 'wrongful', 'for']
# company:- Baloyi
# words_after_ending_loc
# ['a', 'non-executive', 'director']
# words_before_starting_loc
# ['of', 'services', 'the']
# company:- Absa
# words_after_ending_loc
# ['said', 'in', 'an']
# words_before_starting_loc
# ['Johannesburg-based', 'company', 'holding']
# company:- Baloyi
# words_after_ending_loc
# ['said', '<markup>Absa</markup>', "didn't"]
# words_before_starting_loc
# ['today', 'statement', 'e-mailed']
# company:- Absa
# words_after_ending_loc
# ["didn't", 'give', 'her']
# words_before_starting_loc
# ['said', 'Baloyi', 'today']
# company:- Fidentia
# words_after_ending_loc
# ['was', 'put', 'under']
# words_before_starting_loc
# ['Town-based', 'Cape', 'e-mail']
# company:- Baloyi
# words_after_ending_loc
# ['is', 'a', 'director']
# words_before_starting_loc
# ['funds', 'client', 'stealing']
# company:- Hands
# words_after_ending_loc
# ['a', '<markup>Fidentia</markup>', 'unit']
# words_before_starting_loc
# ['Living', 'of', 'director']
# company:- Fidentia
# words_after_ending_loc
# ['unit', 'that', 'administered']
# words_before_starting_loc
# ['a', 'Hands', 'Living']
# company:- Fidentia
# words_after_ending_loc
# ['Chairman', 'Arthur', 'Brown']
# words_before_starting_loc
# ['documents', 'court', 'to']
# company:- Brown
# words_after_ending_loc
# ['and', 'director', 'Graham']
# words_before_starting_loc
# ['Arthur', 'Chairman', '<markup>Fidentia</markup>']
# company:- Maddock
# words_after_ending_loc
# ['were', 'granted', 'bail']
# words_before_starting_loc
# ['Graham', 'director', 'and']
# company:- Town
# words_after_ending_loc
# ['court', 'yesterday', 'pending']
# words_before_starting_loc
# ['Cape', 'a', 'by']
# company:- Brown
# words_after_ending_loc
# ['is', 'still', 'in']
# words_before_starting_loc
# ['allegations', 'the', 'denied']
# company:- Association
# words_after_ending_loc
# ['said', 'citing', "Brown's"]
# words_before_starting_loc
# ['Press', 'African', 'South']
# company:- Brown's
# words_after_ending_loc
# ['lawyers', 'who', 'they']
# words_before_starting_loc
# ['citing', 'said', 'Association']
# company:- Absa
# words_after_ending_loc
# ['is', 'controlled', 'by']
# words_before_starting_loc
# ['identify', "didn't", 'they']
# company:- UK's
# words_after_ending_loc
# ['third-largest', 'bank', 'To']
# words_before_starting_loc
# ['the', 'Plc</markup>', '<markup>Barclays']
# company:- Wessels
# words_after_ending_loc
# ['in', 'Johannesburg', 'at']
# words_before_starting_loc
# ['Vernon', 'story:', 'this']
# company:- Johannesburg
# words_after_ending_loc
# ['at', 'vwessels@bloombergnet', 'To']
# words_before_starting_loc
# ['in', 'Wessels', 'Vernon']
# company:- Cox
# words_after_ending_loc
# ['at', 'acox2@bloombergnet', 'Frank']
# words_before_starting_loc
# ['Adrian', 'story:', 'this']
# company:- Connelly
# words_after_ending_loc
# ['at', 'fconnelly@bloombergnet']
# words_before_starting_loc
# ['Frank', 'acox2@bloombergnet', 'at']
# possible_words-
# ['<markup>ACE', 'Aviation', 'Holdings', 'Inc</markup>', 'ACE/H', 'must', 'give', 'raises', 'to', 'pilots', 'at', '<markup>Air', 'Canada</markup>', 'the', "country's", 'largest', 'airline', 'and', 'flight', 'attendants', 'at', 'the', "company's", 'regional', 'carrier', 'two', 'arbitrators', 'ruled', 'The', '3100', 'pilots', 'represented', 'by', 'the', '<markup>Air', 'Canada</markup>', 'Pilots', 'Association', 'will', 'get', 'a', '2', 'percent', 'wage', 'increase', 'effective', 'July', '2006', '175', 'percent', 'in', 'July', '2007', 'and', '175', 'percent', 'in', 'July', '2008', 'in', 'a', 'settlement', 'handed', 'down', 'by', 'arbitrator', 'Douglas', 'Stanley', 'Montreal-based', '<markup>ACE</markup>', 'said', 'today', 'in', 'a', 'statement', 'The', 'pilot', 'award', 'is', 'the', 'third', 'arbitrated', 'settlement', 'for', '<markup>Air', 'Canada</markup>', 'which', 'had', 'scheduled', 'wage', 'talks', 'with', 'all', 'its', 'major', 'labor', 'groups', 'this', 'year', 'Mechanics', 'received', '5', 'percent', 'over', 'three', 'years', 'in', 'an', 'August', 'settlement', 'and', 'sales', 'and', 'service', 'employees', 'got', 'a', '45', 'percent', 'wage', 'increase', 'over', 'the', 'same', 'period', 'in', 'a', 'July', 'award', 'Jazz', 'the', 'regional', 'airline', '80', 'percent', 'owned', 'by', '<markup>ACE</markup>', 'must', 'pay', 'the', '740', 'flight', 'attendants', 'represented', 'by', 'Teamsters', 'Canada', '1', 'percent', 'more', 'effective', 'July', '2006', '175', 'percent', 'on', 'July', '2007', 'and', '175', 'percent', 'on', 'July', '2008', 'Halifax-based', 'Jazz', 'said', 'today', 'in', 'a', 'statement', 'The', 'raises', 'were', 'ordered', 'by', 'arbitrator', 'Michel', 'Picher', 'matching', 'those', 'he', 'issued', 'to', '1660', 'other', 'Jazz', 'employees', 'in', 'July', '<markup>ACE</markup>', 'is', 'awaiting', 'an', 'arbitrated', 'settlement', 'with', 'the', 'Canadian', 'Union', 'of', 'Public', 'Employees', 'which', 'represents', '6000', '<markup>Air', 'Canada</markup>', 'flight', 'attendants', 'Shares', 'of', '<markup>ACE</markup>', 'fell', 'C$251', 'or', '65', 'percent', 'to', 'C$3624', 'at', '4:10', 'pm', 'on', 'the', 'Toronto', 'Stock', 'Exchange', 'Units', 'of', 'Jazz', 'Air', 'Income', 'Fund', 'which', 'owns', '20', 'percent', 'of', '<markup>ACE</markup>', "'s", 'regional', 'carrier', 'fell', 'C$178', 'or', '19', 'percent', 'to', 'C$750', 'after', 'the', 'Canadian', 'government', 'said', 'yesterday', 'it', 'planned', 'to', 'tax', 'income', 'trusts', 'Income', 'trusts', 'avoid', 'paying', 'most', 'corporate', 'taxes', 'by', 'distributing', 'most', 'of', 'their', 'cash', 'flow', 'to', 'investors', 'To', 'contact', 'the', 'reporter', 'on', 'this', 'story:', 'Doug', 'Alexander', 'in', 'Toronto', 'at', 'dalexander3@bloombergnet', 'To', 'contact', 'the', 'editor', 'responsible', 'for', 'this', 'story:', 'Dave', 'Versical', 'at', 'dversical@bloombergnet']
# company:- ACE Aviation Holdings Inc
# words_after_ending_loc
# ['ACE/H', 'must', 'give']
# words_before_starting_loc
# []
# company:- Toronto Stock Exchange Units
# words_after_ending_loc
# ['of', 'Jazz', 'Air']
# words_before_starting_loc
# ['the', 'on', 'pm']
# company:- Jazz Air Income Fund
# words_after_ending_loc
# ['which', 'owns', '20']
# words_before_starting_loc
# ['of', 'Units', 'Exchange']
# company:- Douglas Stanley Montreal-based
# words_after_ending_loc
# ['<markup>ACE</markup>', 'said', 'today']
# words_before_starting_loc
# ['arbitrator', 'by', 'down']
# company:- Toronto Stock Exchange
# words_after_ending_loc
# ['Units', 'of', 'Jazz']
# words_before_starting_loc
# ['the', 'on', 'pm']
# company:- Stock Exchange Units
# words_after_ending_loc
# ['of', 'Jazz', 'Air']
# words_before_starting_loc
# ['Toronto', 'the', 'on']
# company:- Jazz Air Income
# words_after_ending_loc
# ['Fund', 'which', 'owns']
# words_before_starting_loc
# ['of', 'Units', 'Exchange']
# company:- Air Income Fund
# words_after_ending_loc
# ['which', 'owns', '20']
# words_before_starting_loc
# ['Jazz', 'of', 'Units']
# company:- Aviation Holdings
# words_after_ending_loc
# ['Inc</markup>', 'ACE/H', 'must']
# words_before_starting_loc
# ['<markup>ACE']
# company:- Air Canada
# words_after_ending_loc
# ['the', "country's", 'largest']
# words_before_starting_loc
# ['at', 'pilots', 'to']
# company:- Air Canada
# words_after_ending_loc
# ['Pilots', 'Association', 'will']
# words_before_starting_loc
# ['the', 'by', 'represented']
# company:- Pilots Association
# words_after_ending_loc
# ['will', 'get', 'a']
# words_before_starting_loc
# ['Canada</markup>', '<markup>Air', 'the']
# company:- Douglas Stanley
# words_after_ending_loc
# ['Montreal-based', '<markup>ACE</markup>', 'said']
# words_before_starting_loc
# ['arbitrator', 'by', 'down']
# company:- Stanley Montreal-based
# words_after_ending_loc
# ['<markup>ACE</markup>', 'said', 'today']
# words_before_starting_loc
# ['Douglas', 'arbitrator', 'by']
# company:- Air Canada
# words_after_ending_loc
# ['which', 'had', 'scheduled']
# words_before_starting_loc
# ['for', 'settlement', 'arbitrated']
# company:- Teamsters Canada
# words_after_ending_loc
# ['1', 'percent', 'more']
# words_before_starting_loc
# ['by', 'represented', 'attendants']
# company:- Halifax-based Jazz
# words_after_ending_loc
# ['said', 'today', 'in']
# words_before_starting_loc
# ['2008', 'July', 'on']
# company:- Michel Picher
# words_after_ending_loc
# ['matching', 'those', 'he']
# words_before_starting_loc
# ['arbitrator', 'by', 'ordered']
# company:- Canadian Union
# words_after_ending_loc
# ['of', 'Public', 'Employees']
# words_before_starting_loc
# ['the', 'with', 'settlement']
# company:- Public Employees
# words_after_ending_loc
# ['which', 'represents', '6000']
# words_before_starting_loc
# ['of', 'Union', 'Canadian']
# company:- Air Canada
# words_after_ending_loc
# ['flight', 'attendants', 'Shares']
# words_before_starting_loc
# ['6000', 'represents', 'which']
# company:- Toronto Stock
# words_after_ending_loc
# ['Exchange', 'Units', 'of']
# words_before_starting_loc
# ['the', 'on', 'pm']
# company:- Stock Exchange
# words_after_ending_loc
# ['Units', 'of', 'Jazz']
# words_before_starting_loc
# ['Toronto', 'the', 'on']
# company:- Exchange Units
# words_after_ending_loc
# ['of', 'Jazz', 'Air']
# words_before_starting_loc
# ['Stock', 'Toronto', 'the']
# company:- Jazz Air
# words_after_ending_loc
# ['Income', 'Fund', 'which']
# words_before_starting_loc
# ['of', 'Units', 'Exchange']
# company:- Air Income
# words_after_ending_loc
# ['Fund', 'which', 'owns']
# words_before_starting_loc
# ['Jazz', 'of', 'Units']
# company:- Income Fund
# words_after_ending_loc
# ['which', 'owns', '20']
# words_before_starting_loc
# ['Air', 'Jazz', 'of']
# company:- Doug Alexander
# words_after_ending_loc
# ['in', 'Toronto', 'at']
# words_before_starting_loc
# ['story:', 'this', 'on']
# company:- Dave Versical
# words_after_ending_loc
# ['at', 'dversical@bloombergnet']
# words_before_starting_loc
# ['story:', 'this', 'for']
# company:- ACE/H
# words_after_ending_loc
# ['must', 'give', 'raises']
# words_before_starting_loc
# ['Inc</markup>', 'Holdings', 'Aviation']
# company:- Association
# words_after_ending_loc
# ['will', 'get', 'a']
# words_before_starting_loc
# ['Pilots', 'Canada</markup>', '<markup>Air']
# company:- ACE
# words_after_ending_loc
# ['said', 'today', 'in']
# words_before_starting_loc
# ['Montreal-based', 'Stanley', 'Douglas']
# company:- Mechanics
# words_after_ending_loc
# ['received', '5', 'percent']
# words_before_starting_loc
# ['year', 'this', 'groups']
# company:- August
# words_after_ending_loc
# ['settlement', 'and', 'sales']
# words_before_starting_loc
# ['an', 'in', 'years']
# company:- July
# words_after_ending_loc
# ['award', 'Jazz', 'the']
# words_before_starting_loc
# ['a', 'in', 'period']
# company:- Jazz
# words_after_ending_loc
# ['the', 'regional', 'airline']
# words_before_starting_loc
# ['award', 'July', 'a']
# company:- ACE
# words_after_ending_loc
# ['must', 'pay', 'the']
# words_before_starting_loc
# ['by', 'owned', 'percent']
# company:- Jazz
# words_after_ending_loc
# ['said', 'today', 'in']
# words_before_starting_loc
# ['Halifax-based', '2008', 'July']
# company:- Picher
# words_after_ending_loc
# ['matching', 'those', 'he']
# words_before_starting_loc
# ['Michel', 'arbitrator', 'by']
# company:- Jazz
# words_after_ending_loc
# ['employees', 'in', 'July']
# words_before_starting_loc
# ['other', '1660', 'to']
# company:- ACE
# words_after_ending_loc
# ['is', 'awaiting', 'an']
# words_before_starting_loc
# ['July', 'in', 'employees']
# company:- Union
# words_after_ending_loc
# ['of', 'Public', 'Employees']
# words_before_starting_loc
# ['Canadian', 'the', 'with']
# company:- Employees
# words_after_ending_loc
# ['which', 'represents', '6000']
# words_before_starting_loc
# ['Public', 'of', 'Union']
# company:- Shares
# words_after_ending_loc
# ['of', '<markup>ACE</markup>', 'fell']
# words_before_starting_loc
# ['attendants', 'flight', 'Canada</markup>']
# company:- ACE
# words_after_ending_loc
# ['fell', 'C$251', 'or']
# words_before_starting_loc
# ['of', 'Shares', 'attendants']
# company:- C$251
# words_after_ending_loc
# ['or', '65', 'percent']
# words_before_starting_loc
# ['fell', '<markup>ACE</markup>', 'of']
# company:- C$3624
# words_after_ending_loc
# ['at', '4:10', 'pm']
# words_before_starting_loc
# ['to', 'percent', '65']
# company:- Units
# words_after_ending_loc
# ['of', 'Jazz', 'Air']
# words_before_starting_loc
# ['Exchange', 'Stock', 'Toronto']
# company:- ACE
# words_after_ending_loc
# ["'s", 'regional', 'carrier']
# words_before_starting_loc
# ['of', 'percent', '20']
# company:- C$178
# words_after_ending_loc
# ['or', '19', 'percent']
# words_before_starting_loc
# ['fell', 'carrier', 'regional']
# company:- C$750
# words_after_ending_loc
# ['after', 'the', 'Canadian']
# words_before_starting_loc
# ['to', 'percent', '19']
# company:- Canadian
# words_after_ending_loc
# ['government', 'said', 'yesterday']
# words_before_starting_loc
# ['the', 'after', 'C$750']
# company:- Income
# words_after_ending_loc
# ['trusts', 'avoid', 'paying']
# words_before_starting_loc
# ['trusts', 'income', 'tax']
# company:- Alexander
# words_after_ending_loc
# ['in', 'Toronto', 'at']
# words_before_starting_loc
# ['Doug', 'story:', 'this']
# company:- Toronto
# words_after_ending_loc
# ['at', 'dalexander3@bloombergnet', 'To']
# words_before_starting_loc
# ['in', 'Alexander', 'Doug']
# company:- Versical
# words_after_ending_loc
# ['at', 'dversical@bloombergnet']
# words_before_starting_loc
# ['Dave', 'story:', 'this']
# possible_words-
# ['A', 'group', 'of', '<markup>Adelphia', 'Communications', 'Corp</markup>', 'noteholders', "shouldn't", 'have', 'to', 'post', 'a', '$13', 'billion', 'bond', 'while', 'a', 'judge', 'considers', 'objections', 'to', 'the', "company's", 'bankruptcy', 'exit', 'plan', 'the', "group's", 'lawyer', 'told', 'a', 'federal', 'appeals', 'court', 'The', 'holders', 'of', '$11', 'billion', 'in', '<markup>Adelphia</markup>', 'notes', 'won', 'a', 'stay', 'of', 'the', 'bankruptcy', 'plan', 'on', 'Jan', '24', 'from', 'a', 'federal', 'district', 'judge', 'who', 'said', 'they', 'stood', 'to', 'get', '$250', 'million', 'if', 'they', 'prevailed', 'and', 'ordered', 'them', 'to', 'post', 'the', 'bond', 'within', 'three', 'days', 'The', 'next', 'day', 'an', 'appeals', 'judge', 'suspended', 'the', 'bond', 'requirement', 'until', 'a', 'panel', 'of', 'judges', 'could', 'hear', 'arguments', 'on', 'the', 'issue', 'To', 'get', 'a', '$250', 'million', 'upside', "they're", 'being', 'told', 'to', 'invest', 'and', 'put', 'at', 'risk', '$13', 'billion', 'Martin', 'Bienenstock', 'a', 'lawyer', 'for', 'the', 'noteholders', 'told', 'the', 'two-judge', 'panel', 'today', 'in', 'New', 'York', "There's", 'too', 'much', "that's", 'not', 'in', 'our', "clients'", 'control', 'to', 'risk', '$13', 'billion', 'The', 'noteholders', 'object', 'to', 'the', 'value', 'placed', 'on', 'the', 'shares', 'in', '<markup>Time', 'Warner', 'Cable', 'Inc</markup>', 'TWC', 'that', '<markup>Adelphia</markup>', 'received', 'when', 'it', 'sold', 'its', 'assets', 'to', '<markup>Time', 'Warner', 'Inc</markup>', 'TWX', 'and', '<markup>Comcast', 'Corp</markup>', 'CMCSA', 'last', 'year', 'The', 'Jan', '24', 'delay', 'imposed', 'by', 'US', 'District', 'Judge', 'Shira', 'Scheindlin', 'of', 'New', 'York', 'postponed', 'full', 'trading', 'in', 'the', 'Time', 'Warner', 'Cable', 'shares', 'which', 'creditors', 'will', 'get', 'as', 'part', 'of', 'their', 'payout', 'from', '<markup>Adelphia</markup>', 'once', 'the', 'fifth-biggest', 'US', 'cable', 'TV', 'company', 'The', 'judges', "didn't", 'rule', 'today', 'on', 'the', 'bond', 'question', 'If', 'the', 'noteholders', 'lose', 'their', 'appeal', 'of', '<markup>Adelphia</markup>', "'s", 'bankruptcy', 'plan', 'the', 'bond', 'would', 'be', 'used', 'to', 'cover', 'whatever', 'damages', 'other', '<markup>Adelphia</markup>', 'creditors', 'suffered', 'because', 'of', 'the', 'delay', 'in', 'implementing', 'the', 'plan', 'Unreasonable', 'Bienenstock', 'of', 'New', 'York', "'s", '<markup>Weil', 'Gotshal', 'And', 'Manges</markup>', 'told', 'appeals', 'court', 'judges', 'Robert', 'D', 'Sack', 'and', 'Jon', 'O', 'Newman', 'that', '<markup>Adelphia</markup>', 'and', 'those', 'of', 'its', 'creditors', 'that', 'approve', 'of', 'the', 'plan', 'are', 'trying', 'to', 'prevent', 'the', 'noteholders', 'from', 'appealing', 'by', 'calling', 'for', 'an', 'unreasonable', 'bond', 'He', 'argued', 'that', "it's", 'unfair', 'for', 'his', '11', 'clients', 'which', 'include', '<markup>Bank', 'of', 'America', 'Corp</markup>', 'subsidiary', '<markup>Bank', 'of', 'America', 'Securities', 'LLC</markup>', 'and', 'a', 'unit', 'of', '<markup>Lehman', 'Brothers', 'Holdings', 'Inc</markup>', 'to', 'have', 'to', 'indemnify', 'the', 'thousands', 'of', 'other', 'creditors', 'in', 'the', 'case', 'David', 'M', 'Friedman', 'an', 'attorney', 'for', '<markup>Adelphia</markup>', "'s", 'unsecured', 'creditors', 'argued', 'that', 'the', 'bond', 'is', 'needed', 'to', 'cover', 'costs', 'including', '$700', 'million', 'in', 'underwriting', 'expenses', 'for', 'a', 'public', 'offering', 'of', 'the', 'cable', 'stock', 'if', 'the', 'plan', 'delay', 'prevents', 'the', 'shares', 'from', 'being', 'distributed', 'to', 'creditors']
# company:- US District Judge Shira Scheindlin
# words_after_ending_loc
# ['of', 'New', 'York']
# words_before_starting_loc
# ['by', 'imposed', 'delay']
# company:- Time Warner Cable Inc
# words_after_ending_loc
# ['TWC', 'that', '<markup>Adelphia</markup>']
# words_before_starting_loc
# ['in', 'shares', 'the']
# company:- US District Judge Shira
# words_after_ending_loc
# ['Scheindlin', 'of', 'New']
# words_before_starting_loc
# ['by', 'imposed', 'delay']
# company:- District Judge Shira Scheindlin
# words_after_ending_loc
# ['of', 'New', 'York']
# words_before_starting_loc
# ['US', 'by', 'imposed']
# company:- Weil Gotshal And Manges
# words_after_ending_loc
# ['told', 'appeals', 'court']
# words_before_starting_loc
# ["'s", 'York', 'New']
# company:- Lehman Brothers Holdings Inc
# words_after_ending_loc
# ['to', 'have', 'to']
# words_before_starting_loc
# ['of', 'unit', 'a']
# company:- Adelphia Communications Corp
# words_after_ending_loc
# ['noteholders', "shouldn't", 'have']
# words_before_starting_loc
# ['of', 'group', 'A']
# company:- New York There's
# words_after_ending_loc
# ['too', 'much', "that's"]
# words_before_starting_loc
# ['in', 'today', 'panel']
# company:- Time Warner Inc
# words_after_ending_loc
# ['TWX', 'and', '<markup>Comcast']
# words_before_starting_loc
# ['to', 'assets', 'its']
# company:- US District Judge
# words_after_ending_loc
# ['Shira', 'Scheindlin', 'of']
# words_before_starting_loc
# ['by', 'imposed', 'delay']
# company:- District Judge Shira
# words_after_ending_loc
# ['Scheindlin', 'of', 'New']
# words_before_starting_loc
# ['US', 'by', 'imposed']
# company:- Judge Shira Scheindlin
# words_after_ending_loc
# ['of', 'New', 'York']
# words_before_starting_loc
# ['District', 'US', 'by']
# company:- Time Warner Cable
# words_after_ending_loc
# ['shares', 'which', 'creditors']
# words_before_starting_loc
# ['the', 'in', 'trading']
# company:- Robert D Sack
# words_after_ending_loc
# ['and', 'Jon', 'O']
# words_before_starting_loc
# ['judges', 'court', 'appeals']
# company:- Jon O Newman
# words_after_ending_loc
# ['that', '<markup>Adelphia</markup>', 'and']
# words_before_starting_loc
# ['and', 'Sack', 'D']
# company:- David M Friedman
# words_after_ending_loc
# ['an', 'attorney', 'for']
# words_before_starting_loc
# ['case', 'the', 'in']
# company:- Martin Bienenstock
# words_after_ending_loc
# ['a', 'lawyer', 'for']
# words_before_starting_loc
# ['billion', '$13', 'risk']
# company:- New York
# words_after_ending_loc
# ["There's", 'too', 'much']
# words_before_starting_loc
# ['in', 'today', 'panel']
# company:- York There's
# words_after_ending_loc
# ['too', 'much', "that's"]
# words_before_starting_loc
# ['New', 'in', 'today']
# company:- Warner Cable
# words_after_ending_loc
# ['Inc</markup>', 'TWC', 'that']
# words_before_starting_loc
# ['<markup>Time', 'in', 'shares']
# company:- Comcast Corp
# words_after_ending_loc
# ['CMCSA', 'last', 'year']
# words_before_starting_loc
# ['and', 'TWX', 'Inc</markup>']
# company:- The Jan
# words_after_ending_loc
# ['24', 'delay', 'imposed']
# words_before_starting_loc
# ['year', 'last', 'CMCSA']
# company:- US District
# words_after_ending_loc
# ['Judge', 'Shira', 'Scheindlin']
# words_before_starting_loc
# ['by', 'imposed', 'delay']
# company:- District Judge
# words_after_ending_loc
# ['Shira', 'Scheindlin', 'of']
# words_before_starting_loc
# ['US', 'by', 'imposed']
# company:- Judge Shira
# words_after_ending_loc
# ['Scheindlin', 'of', 'New']
# words_before_starting_loc
# ['District', 'US', 'by']
# company:- Shira Scheindlin
# words_after_ending_loc
# ['of', 'New', 'York']
# words_before_starting_loc
# ['Judge', 'District', 'US']
# company:- New York
# words_after_ending_loc
# ['postponed', 'full', 'trading']
# words_before_starting_loc
# ['of', 'Scheindlin', 'Shira']
# company:- Time Warner
# words_after_ending_loc
# ['Cable', 'shares', 'which']
# words_before_starting_loc
# ['the', 'in', 'trading']
# company:- Warner Cable
# words_after_ending_loc
# ['shares', 'which', 'creditors']
# words_before_starting_loc
# ['Time', 'the', 'in']
# company:- Unreasonable Bienenstock
# words_after_ending_loc
# ['of', 'New', 'York']
# words_before_starting_loc
# ['plan', 'the', 'implementing']
# company:- New York
# words_after_ending_loc
# ["'s", '<markup>Weil', 'Gotshal']
# words_before_starting_loc
# ['of', 'Bienenstock', 'Unreasonable']
# company:- Gotshal And
# words_after_ending_loc
# ['Manges</markup>', 'told', 'appeals']
# words_before_starting_loc
# ['<markup>Weil', "'s", 'York']
# company:- Robert D
# words_after_ending_loc
# ['Sack', 'and', 'Jon']
# words_before_starting_loc
# ['judges', 'court', 'appeals']
# company:- D Sack
# words_after_ending_loc
# ['and', 'Jon', 'O']
# words_before_starting_loc
# ['Robert', 'judges', 'court']
# company:- Jon O
# words_after_ending_loc
# ['Newman', 'that', '<markup>Adelphia</markup>']
# words_before_starting_loc
# ['and', 'Sack', 'D']
# company:- O Newman
# words_after_ending_loc
# ['that', '<markup>Adelphia</markup>', 'and']
# words_before_starting_loc
# ['Jon', 'and', 'Sack']
# company:- America Securities
# words_after_ending_loc
# ['LLC</markup>', 'and', 'a']
# words_before_starting_loc
# ['of', '<markup>Bank', 'subsidiary']
# company:- Brothers Holdings
# words_after_ending_loc
# ['Inc</markup>', 'to', 'have']
# words_before_starting_loc
# ['<markup>Lehman', 'of', 'unit']
# company:- David M
# words_after_ending_loc
# ['Friedman', 'an', 'attorney']
# words_before_starting_loc
# ['case', 'the', 'in']
# company:- M Friedman
# words_after_ending_loc
# ['an', 'attorney', 'for']
# words_before_starting_loc
# ['David', 'case', 'the']
# company:- Adelphia
# words_after_ending_loc
# ['notes', 'won', 'a']
# words_before_starting_loc
# ['in', 'billion', '$11']
# company:- Bienenstock
# words_after_ending_loc
# ['a', 'lawyer', 'for']
# words_before_starting_loc
# ['Martin', 'billion', '$13']
# company:- There's
# words_after_ending_loc
# ['too', 'much', "that's"]
# words_before_starting_loc
# ['York', 'New', 'in']
# company:- TWC
# words_after_ending_loc
# ['that', '<markup>Adelphia</markup>', 'received']
# words_before_starting_loc
# ['Inc</markup>', 'Cable', 'Warner']
# company:- Adelphia
# words_after_ending_loc
# ['received', 'when', 'it']
# words_before_starting_loc
# ['that', 'TWC', 'Inc</markup>']
# company:- TWX
# words_after_ending_loc
# ['and', '<markup>Comcast', 'Corp</markup>']
# words_before_starting_loc
# ['Inc</markup>', 'Warner', '<markup>Time']
# company:- CMCSA
# words_after_ending_loc
# ['last', 'year', 'The']
# words_before_starting_loc
# ['Corp</markup>', '<markup>Comcast', 'and']
# company:- Scheindlin
# words_after_ending_loc
# ['of', 'New', 'York']
# words_before_starting_loc
# ['Shira', 'Judge', 'District']
# company:- York
# words_after_ending_loc
# ['postponed', 'full', 'trading']
# words_before_starting_loc
# ['New', 'of', 'Scheindlin']
# company:- Cable
# words_after_ending_loc
# ['shares', 'which', 'creditors']
# words_before_starting_loc
# ['Warner', 'Time', 'the']
# company:- Adelphia
# words_after_ending_loc
# ['once', 'the', 'fifth-biggest']
# words_before_starting_loc
# ['from', 'payout', 'their']
# company:- US
# words_after_ending_loc
# ['cable', 'TV', 'company']
# words_before_starting_loc
# ['fifth-biggest', 'the', 'once']
# company:- TV
# words_after_ending_loc
# ['company', 'The', 'judges']
# words_before_starting_loc
# ['cable', 'US', 'fifth-biggest']
# company:- If
# words_after_ending_loc
# ['the', 'noteholders', 'lose']
# words_before_starting_loc
# ['question', 'bond', 'the']
# company:- Adelphia
# words_after_ending_loc
# ["'s", 'bankruptcy', 'plan']
# words_before_starting_loc
# ['of', 'appeal', 'their']
# company:- Adelphia
# words_after_ending_loc
# ['creditors', 'suffered', 'because']
# words_before_starting_loc
# ['other', 'damages', 'whatever']
# company:- Bienenstock
# words_after_ending_loc
# ['of', 'New', 'York']
# words_before_starting_loc
# ['Unreasonable', 'plan', 'the']
# company:- Sack
# words_after_ending_loc
# ['and', 'Jon', 'O']
# words_before_starting_loc
# ['D', 'Robert', 'judges']
# company:- Newman
# words_after_ending_loc
# ['that', '<markup>Adelphia</markup>', 'and']
# words_before_starting_loc
# ['O', 'Jon', 'and']
# company:- Adelphia
# words_after_ending_loc
# ['and', 'those', 'of']
# words_before_starting_loc
# ['that', 'Newman', 'O']
# company:- Friedman
# words_after_ending_loc
# ['an', 'attorney', 'for']
# words_before_starting_loc
# ['M', 'David', 'case']
# company:- Adelphia
# words_after_ending_loc
# ["'s", 'unsecured', 'creditors']
# words_before_starting_loc
# ['for', 'attorney', 'an']
# possible_words-
# ['<markup>Advanced', 'Marketing', 'Services', 'Inc</markup>', 'MKTS', 'a', 'bankrupt', 'book', 'distributor', 'for', 'warehouse', 'retailers', "<markup>Sam's", 'Club</markup>', 'and', '<markup>Costco', 'Wholesale', 'Corp</markup>', 'agreed', 'to', 'sell', 'most', 'of', 'its', 'assets', 'to', 'rival', 'distributor', '<markup>Baker', 'And', 'Taylor', 'Inc</markup>', 'Terms', 'were', 'not', 'disclosed', 'The', 'proposed', 'sale', "doesn't", 'include', '<markup>Advanced', 'Marketing</markup>', "'s", 'small-publisher', 'division', 'which', 'will', 'be', 'sold', 'through', 'a', 'court-sanctioned', 'auction', 'US', 'Bankruptcy', 'Judge', 'Christopher', 'Sontchi', 'ruled', 'today', 'Sontchi', 'in', 'Wilmington', 'Delaware', 'must', 'approve', 'both', 'sales', 'which', 'the', 'company', 'said', 'should', 'close', 'by', 'March', '15', '<markup>Baker', 'And', 'Taylor</markup>', 'is', 'a', 'recognized', 'leader', 'in', 'the', 'book', 'distribution', 'industry', 'and', 'has', 'the', 'experience', 'to', 'seamlessly', 'assume', 'operations', '<markup>Advanced', 'Marketing</markup>', 'Chief', 'Executive', 'Officer', 'Gary', 'Rautenstrauch', 'said', 'in', 'statement', 'San', 'Diego-based', '<markup>Advanced', 'Marketing</markup>', 'filed', 'for', 'bankruptcy', 'protection', 'Dec', '29', 'three', 'years', 'after', 'the', 'US', 'Justice', 'Department', 'and', 'the', 'Securities', 'and', 'Exchange', 'Commission', 'began', 'investigating', 'its', 'financial', 'reporting', 'and', 'cooperative', 'advertising', 'practices', 'according', 'to', 'court', 'papers', 'Two', '<markup>Advanced', 'Marketing</markup>', 'employees', 'and', 'one', 'officer', 'were', 'sentenced', 'in', 'connection', 'with', 'the', 'Justice', 'Department', 'probe', 'The', 'company', 'has', 'resolved', 'all', 'of', 'the', 'shareholder', 'suits', 'it', 'had', 'faced', 'Creditors', 'Balk', 'Details', 'of', 'the', 'sale', 'to', '<markup>Baker', 'And', 'Taylor</markup>', 'will', 'be', 'filed', 'with', 'the', 'court', 'in', 'Wilmington', 'by', 'Feb', '16', 'when', 'Advanced', 'Marketing', 'said', 'it', 'would', 'ask', 'Sontchi', 'to', 'approve', 'the', 'rules', 'governing', 'the', 'auction', 'A', 'separate', 'auction', 'for', 'the', "company's", 'Publishers', 'Group', 'West', 'Inc', 'unit', 'will', 'be', 'held', 'Feb', '15', 'Spokespersons', 'for', '<markup>Advanced', 'Marketing</markup>', 'and', '<markup>Baker', 'And', 'Taylor</markup>', 'did', 'not', 'immediately', 'return', 'phone', 'calls', 'seeking', 'comment']
# company:- US Bankruptcy Judge Christopher Sontchi
# words_after_ending_loc
# ['ruled', 'today', 'Sontchi']
# words_before_starting_loc
# ['auction', 'court-sanctioned', 'a']
# company:- Chief Executive Officer Gary Rautenstrauch
# words_after_ending_loc
# ['said', 'in', 'statement']
# words_before_starting_loc
# ['Marketing</markup>', '<markup>Advanced', 'operations']
# company:- Advanced Marketing Services Inc
# words_after_ending_loc
# ['MKTS', 'a', 'bankrupt']
# words_before_starting_loc
# []
# company:- Baker And Taylor Inc
# words_after_ending_loc
# ['Terms', 'were', 'not']
# words_before_starting_loc
# ['distributor', 'rival', 'to']
# company:- US Bankruptcy Judge Christopher
# words_after_ending_loc
# ['Sontchi', 'ruled', 'today']
# words_before_starting_loc
# ['auction', 'court-sanctioned', 'a']
# company:- Bankruptcy Judge Christopher Sontchi
# words_after_ending_loc
# ['ruled', 'today', 'Sontchi']
# words_before_starting_loc
# ['US', 'auction', 'court-sanctioned']
# company:- Chief Executive Officer Gary
# words_after_ending_loc
# ['Rautenstrauch', 'said', 'in']
# words_before_starting_loc
# ['Marketing</markup>', '<markup>Advanced', 'operations']
# company:- Executive Officer Gary Rautenstrauch
# words_after_ending_loc
# ['said', 'in', 'statement']
# words_before_starting_loc
# ['Chief', 'Marketing</markup>', '<markup>Advanced']
# company:- Publishers Group West Inc
# words_after_ending_loc
# ['unit', 'will', 'be']
# words_before_starting_loc
# ["company's", 'the', 'for']
# company:- Costco Wholesale Corp
# words_after_ending_loc
# ['agreed', 'to', 'sell']
# words_before_starting_loc
# ['and', 'Club</markup>', "<markup>Sam's"]
# company:- US Bankruptcy Judge
# words_after_ending_loc
# ['Christopher', 'Sontchi', 'ruled']
# words_before_starting_loc
# ['auction', 'court-sanctioned', 'a']
# company:- Bankruptcy Judge Christopher
# words_after_ending_loc
# ['Sontchi', 'ruled', 'today']
# words_before_starting_loc
# ['US', 'auction', 'court-sanctioned']
# company:- Judge Christopher Sontchi
# words_after_ending_loc
# ['ruled', 'today', 'Sontchi']
# words_before_starting_loc
# ['Bankruptcy', 'US', 'auction']
# company:- Baker And Taylor
# words_after_ending_loc
# ['is', 'a', 'recognized']
# words_before_starting_loc
# ['15', 'March', 'by']
# company:- Chief Executive Officer
# words_after_ending_loc
# ['Gary', 'Rautenstrauch', 'said']
# words_before_starting_loc
# ['Marketing</markup>', '<markup>Advanced', 'operations']
# company:- Executive Officer Gary
# words_after_ending_loc
# ['Rautenstrauch', 'said', 'in']
# words_before_starting_loc
# ['Chief', 'Marketing</markup>', '<markup>Advanced']
# company:- Officer Gary Rautenstrauch
# words_after_ending_loc
# ['said', 'in', 'statement']
# words_before_starting_loc
# ['Executive', 'Chief', 'Marketing</markup>']
# company:- US Justice Department
# words_after_ending_loc
# ['and', 'the', 'Securities']
# words_before_starting_loc
# ['the', 'after', 'years']
# company:- Creditors Balk Details
# words_after_ending_loc
# ['of', 'the', 'sale']
# words_before_starting_loc
# ['faced', 'had', 'it']
# company:- Baker And Taylor
# words_after_ending_loc
# ['will', 'be', 'filed']
# words_before_starting_loc
# ['to', 'sale', 'the']
# company:- Publishers Group West
# words_after_ending_loc
# ['Inc', 'unit', 'will']
# words_before_starting_loc
# ["company's", 'the', 'for']
# company:- Group West Inc
# words_after_ending_loc
# ['unit', 'will', 'be']
# words_before_starting_loc
# ['Publishers', "company's", 'the']
# company:- Baker And Taylor
# words_after_ending_loc
# ['did', 'not', 'immediately']
# words_before_starting_loc
# ['and', 'Marketing</markup>', '<markup>Advanced']
# company:- Marketing Services
# words_after_ending_loc
# ['Inc</markup>', 'MKTS', 'a']
# words_before_starting_loc
# ['<markup>Advanced']
# company:- Sam's Club
# words_after_ending_loc
# ['and', '<markup>Costco', 'Wholesale']
# words_before_starting_loc
# ['retailers', 'warehouse', 'for']
# company:- And Taylor
# words_after_ending_loc
# ['Inc</markup>', 'Terms', 'were']
# words_before_starting_loc
# ['<markup>Baker', 'distributor', 'rival']
# company:- Advanced Marketing
# words_after_ending_loc
# ["'s", 'small-publisher', 'division']
# words_before_starting_loc
# ['include', "doesn't", 'sale']
# company:- US Bankruptcy
# words_after_ending_loc
# ['Judge', 'Christopher', 'Sontchi']
# words_before_starting_loc
# ['auction', 'court-sanctioned', 'a']
# company:- Bankruptcy Judge
# words_after_ending_loc
# ['Christopher', 'Sontchi', 'ruled']
# words_before_starting_loc
# ['US', 'auction', 'court-sanctioned']
# company:- Judge Christopher
# words_after_ending_loc
# ['Sontchi', 'ruled', 'today']
# words_before_starting_loc
# ['Bankruptcy', 'US', 'auction']
# company:- Christopher Sontchi
# words_after_ending_loc
# ['ruled', 'today', 'Sontchi']
# words_before_starting_loc
# ['Judge', 'Bankruptcy', 'US']
# company:- Wilmington Delaware
# words_after_ending_loc
# ['must', 'approve', 'both']
# words_before_starting_loc
# ['in', 'Sontchi', 'today']
# company:- Advanced Marketing
# words_after_ending_loc
# ['Chief', 'Executive', 'Officer']
# words_before_starting_loc
# ['operations', 'assume', 'seamlessly']
# company:- Chief Executive
# words_after_ending_loc
# ['Officer', 'Gary', 'Rautenstrauch']
# words_before_starting_loc
# ['Marketing</markup>', '<markup>Advanced', 'operations']
# company:- Executive Officer
# words_after_ending_loc
# ['Gary', 'Rautenstrauch', 'said']
# words_before_starting_loc
# ['Chief', 'Marketing</markup>', '<markup>Advanced']
# company:- Officer Gary
# words_after_ending_loc
# ['Rautenstrauch', 'said', 'in']
# words_before_starting_loc
# ['Executive', 'Chief', 'Marketing</markup>']
# company:- Gary Rautenstrauch
# words_after_ending_loc
# ['said', 'in', 'statement']
# words_before_starting_loc
# ['Officer', 'Executive', 'Chief']
# company:- San Diego-based
# words_after_ending_loc
# ['<markup>Advanced', 'Marketing</markup>', 'filed']
# words_before_starting_loc
# ['statement', 'in', 'said']
# company:- Advanced Marketing
# words_after_ending_loc
# ['filed', 'for', 'bankruptcy']
# words_before_starting_loc
# ['Diego-based', 'San', 'statement']
# company:- US Justice
# words_after_ending_loc
# ['Department', 'and', 'the']
# words_before_starting_loc
# ['the', 'after', 'years']
# company:- Justice Department
# words_after_ending_loc
# ['and', 'the', 'Securities']
# words_before_starting_loc
# ['US', 'the', 'after']
# company:- Exchange Commission
# words_after_ending_loc
# ['began', 'investigating', 'its']
# words_before_starting_loc
# ['and', 'Securities', 'the']
# company:- Advanced Marketing
# words_after_ending_loc
# ['employees', 'and', 'one']
# words_before_starting_loc
# ['Two', 'papers', 'court']
# company:- Justice Department
# words_after_ending_loc
# ['probe', 'The', 'company']
# words_before_starting_loc
# ['the', 'with', 'connection']
# company:- Creditors Balk
# words_after_ending_loc
# ['Details', 'of', 'the']
# words_before_starting_loc
# ['faced', 'had', 'it']
# company:- Balk Details
# words_after_ending_loc
# ['of', 'the', 'sale']
# words_before_starting_loc
# ['Creditors', 'faced', 'had']
# company:- Advanced Marketing
# words_after_ending_loc
# ['said', 'it', 'would']
# words_before_starting_loc
# ['when', '16', 'Feb']
# company:- Publishers Group
# words_after_ending_loc
# ['West', 'Inc', 'unit']
# words_before_starting_loc
# ["company's", 'the', 'for']
# company:- Group West
# words_after_ending_loc
# ['Inc', 'unit', 'will']
# words_before_starting_loc
# ['Publishers', "company's", 'the']
# company:- West Inc
# words_after_ending_loc
# ['unit', 'will', 'be']
# words_before_starting_loc
# ['Group', 'Publishers', "company's"]
# company:- Advanced Marketing
# words_after_ending_loc
# ['and', '<markup>Baker', 'And']
# words_before_starting_loc
# ['for', 'Spokespersons', '15']
# company:- MKTS
# words_after_ending_loc
# ['a', 'bankrupt', 'book']
# words_before_starting_loc
# ['Inc</markup>', 'Services', 'Marketing']
# company:- Terms
# words_after_ending_loc
# ['were', 'not', 'disclosed']
# words_before_starting_loc
# ['Inc</markup>', 'Taylor', 'And']
# company:- Sontchi
# words_after_ending_loc
# ['ruled', 'today', 'Sontchi']
# words_before_starting_loc
# ['Christopher', 'Judge', 'Bankruptcy']
# company:- Sontchi
# words_after_ending_loc
# ['in', 'Wilmington', 'Delaware']
# words_before_starting_loc
# ['today', 'ruled', 'Sontchi']
# company:- Delaware
# words_after_ending_loc
# ['must', 'approve', 'both']
# words_before_starting_loc
# ['Wilmington', 'in', 'Sontchi']
# company:- Rautenstrauch
# words_after_ending_loc
# ['said', 'in', 'statement']
# words_before_starting_loc
# ['Gary', 'Officer', 'Executive']
# company:- Department
# words_after_ending_loc
# ['and', 'the', 'Securities']
# words_before_starting_loc
# ['Justice', 'US', 'the']
# company:- Commission
# words_after_ending_loc
# ['began', 'investigating', 'its']
# words_before_starting_loc
# ['Exchange', 'and', 'Securities']
# company:- Department
# words_after_ending_loc
# ['probe', 'The', 'company']
# words_before_starting_loc
# ['Justice', 'the', 'with']
# company:- Details
# words_after_ending_loc
# ['of', 'the', 'sale']
# words_before_starting_loc
# ['Balk', 'Creditors', 'faced']
# company:- Wilmington
# words_after_ending_loc
# ['by', 'Feb', '16']
# words_before_starting_loc
# ['in', 'court', 'the']
# company:- Marketing
# words_after_ending_loc
# ['said', 'it', 'would']
# words_before_starting_loc
# ['Advanced', 'when', '16']
# company:- Sontchi
# words_after_ending_loc
# ['to', 'approve', 'the']
# words_before_starting_loc
# ['ask', 'would', 'it']
# company:- Spokespersons
# words_after_ending_loc
# ['for', '<markup>Advanced', 'Marketing</markup>']
# words_before_starting_loc
# ['15', 'Feb', 'held']

# %%
ngram = ('<markup>Gazprom', 'Lukoil</markup>')
if(len(ngram)>1 and '<markup>' in ngram[0] and '</markup>' in ngram[len(ngram)-1] and
              all((word[0].isupper() or "markup" in word) for word in ngram) and 
              ["<markup>" in word for word in ngram].count(True)==1):
    print "hallo"
# Out:
# hallo

# %%
["markup" in word for word in ngram].count(True)==2
# Out:
# True

# %%
import pycountry
country_names = []
for country in pycountry.countries:
    country_names.append(country.name)
    if hasattr(country,'common_name'):
        country_names.append(country.common_name)
    if hasattr(country, 'official_name'):
        country_names.append(country.official_name)

country_names.append("America")
country_names.append("Korea")
country_names.append("South Korea")
country_names.append("North Korea")
country_names.append("U.S.")
country_names.append("Russia")

if "Russia" in country_names:
    print "YES"
    
continent_list = ['Asia', 'Africa', 'South America', 'North America', 'Antarctica', 'Europe', 'Australia']
# Out:
# YES

# %%
cities = []
with open('world-cities.csv', 'r') as inp:
        for row in csv.reader(inp):
            if(row and row[3] != "" and row[0]!="name"):
                cities.append(row[0])

cities.append('Bombay')
cities.append('New York')
if "Compton" in cities:
    print "YES"

us_states = open('us-states.txt').read().split('\n')
ethni_list = open('ethnicities.txt').read().split('\n')
# Out:
# YES

# %%
desig = open('designations.txt').read().split('\n')
desig_lower = [x.lower() for x in desig]

print desig_lower
# Out:
# ['chief executive officer', 'chief financial officer', 'co-chief executive', 'chief investment officer', 'analyst', 'ceo', 'cio', 'cto', 'cfo', 'manager', 'director', 'president', 'vice-president', 'vice president', 'chief', 'executive', 'officer', 'officers', 'analysts', 'managers', 'directors', 'co-chief', 'co chief']

# %%
pruned_pos = open('pruned_pos.txt').read().split('\n')
stock_x = open('stock-exchange-list.txt').read().split('\n')
unigram_prune = open('unigram-prune-neg.txt').read().split('\n')
special_char = [';', ',', ':', '?']
prune = open('pruning-neg.txt').read().split('\n') 
prune_lower = [x.lower() for x in prune]
suffixes = open('company-suffixes.txt').read().split('\n')
prefixes = open('company-prefixes.txt').read().split('\n')
rows = 0
print len(processed_list)
for doc in processed_list:
    rows += len(doc)
# Out:
# 8115

# %%
print pruned_pos
new_proc_list = []
pruned_list = []

for inst in processed_list:
    if inst[0] not in pruned_pos: 
        if inst[0] in country_names or inst[0] in continent_list or inst[0] in cities or inst[0] in stock_x or inst[0] in us_states:
            pruned_list.append(inst)
        elif "'s" in inst[0]:
            pruned_list.append(inst)
        elif inst[0].endswith('n') and inst[0][:-1] in country_names or str in continent_list:
            pruned_list.append(inst)
        elif "based" in inst[0]:
            pruned_list.append(inst)
        elif any(d in inst[0].lower().split() for d in desig_lower):
            pruned_list.append(inst)
        elif any(p in inst[0].lower().split() for p in prune_lower):
            pruned_list.append(inst)
        elif '(' in inst[0] or ')' in inst[0]:
            pruned_list.append(inst)
        elif any(c in inst[0] for c in special_char):
            pruned_list.append(inst)
        elif len(inst[0].split()) == 1:
            if len(inst[0]) == 1:
                pruned_list.append(inst)
            elif inst[0] in unigram_prune or inst[0] in ethni_list:
                pruned_list.append(inst)
            elif inst[0] == inst[0].upper():
                pruned_list.append(inst)
            elif inst[0] in suffixes or inst[0] in prefixes:
                pruned_list.append(inst)
            else:
                new_proc_list.append(inst)
        else:
            new_proc_list.append(inst)
    else:
        new_proc_list.append(inst)
            
                
print len(pruned_list)
for eg in pruned_list:
    if eg[4] == 1:
        print "HOLY MOLY!"
#writeToCsv(processed_list)
print len(new_proc_list)
print len(pruned_list) + len(new_proc_list)
#print pruned_list
# Out:
# ['ACE', "Sam's Club", 'ICBC', 'KKR', 'CSN', 'Tata', 'Wheeling', "River's Edge Pharmaceuticals LLC", "River's Edge", 'RWE', 'Fremont', 'News Corp', 'GM', 'Liberty', 'Financial Services Authority', 'FSA', 'NZOG', 'Norilsk', 'NTP', 'MPC', 'PPR', 'THQ', 'Nokia', 'RCS', 'Intercontinental Exchange Inc', 'EON', 'RHB', 'WCM', 'Macclesfield', 'Carrefour', 'KPI', 'TXU', 'ECI', 'BP', 'TNK-BP', 'Imperial', 'Zug', 'TDF', 'TMK', "Ivernia Inc's", 'SAIC', 'GE', 'PICC', 'Saku', 'Winterthur', 'ZKB', "Rupert Murdoch's News Corp", 'PIK', 'VTB', 'UBS', 'IGT', 'BHP', 'BBH', 'China Banking Regulatory Commission', 'Compton', 'Centennial', 'NPD', 'HSBC', "Victoria's Secret", 'MAN', 'MBIA', 'Freeport', 'MGIC', 'PMI', 'Stillwater', "Dr Reddy's Laboratories Ltd", "Royal Mail's", '']
# 2914
# 5201
# 8115

# %%
'''thefile = open('pruned_pos.txt', 'w')
for item in pruned_pos:
    #print item
    thefile.write("%s\n" % item)
len(pruned_pos)
print pruned_list'''
# Out:
# 'thefile = open(\'pruned_pos.txt\', \'w\')\nfor item in pruned_pos:\n    #print item\n    thefile.write("%s\n" % item)\nlen(pruned_pos)\nprint pruned_list'

# %%
with open("train_pruned.csv", "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in new_proc_list:
        writer.writerow(val)
